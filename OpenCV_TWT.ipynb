# %% [markdown]
# <a href="https://colab.research.google.com/github/jagrit-goyal/python_assignments/blob/main/OpenCV_TWT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#LECTURE 1

#image reading
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread('/content/jagrit.jpeg', 1);
img = cv2.resize(img , (0,0), fx=0.5,fy=0.5);
# img = cv2.rotate(img , cv2.ROTATE_90_COUNTERCLOCKWISE);
cv2_imshow(img);

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=360x360>

# %%
#another way through matplotlib
import matplotlib.pyplot as plt

img = cv2.imread('/content/jagrit.jpeg', 0);#0 is used for grayscale
if img is not None:
    plt.imshow(img, cmap='gray')  # Display the image in grayscale
    plt.title('Image')
    plt.show()
else:
    print("Error: Image not loaded.")
